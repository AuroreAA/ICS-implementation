# %%
import Pkg; Pkg.add("Robustbase")
# Out:
#    Resolving package versions...
#     Updating `~/.julia/environments/v1.12/Project.toml`
#   [1786b160] + Robustbase v0.2.0
#     Manifest No packages added to or removed from `~/.julia/environments/v1.12/Manifest.toml`

# %%
import Pkg; Pkg.add("ICSTools")
# Out:
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed Distances ─────────── v0.10.12
#    Installed StatisticalTraits ─── v3.5.0
#    Installed Graphics ──────────── v1.1.3
#    Installed NearestNeighbors ──── v0.4.27
#    Installed MCMCDiagnosticTools ─ v0.3.17
#    Installed ICSTools ──────────── v0.1.1
#    Installed Widgets ───────────── v0.6.7
#    Installed Robustbase ────────── v0.2.0
#    Installed MLJModelInterface ─── v1.12.1
#    Installed Cairo ─────────────── v1.1.1
#    Installed StatsPlots ────────── v0.15.8
#    Installed ScientificTypesBase ─ v3.1.0
#    Installed MultivariateStats ─── v0.10.4
#    Installed TableOperations ───── v1.2.0
#    Installed Clustering ────────── v0.15.8
#    Installed Arpack_jll ────────── v3.5.2+0
#    Installed PairPlots ─────────── v3.0.3
#    Installed CairoMakie ────────── v0.15.10
#    Installed Arpack ────────────── v0.5.4
#   Installing 1 artifacts
# ...

# %%
# Load dataset
using Robustbase
X=wood[:,1:5];

# %%
using ICSTools

## Instantiate ICSModel object with all default parameters
ics = ICSModel();
show(ics)
# Out:
# ICS based on two scatter matrices
# S1: cov2
# S1_args: Dict{Symbol, Any}()
# S2: covW
# S2_args: Dict{Symbol, Any}()
#
# Information on the algorithm:
# algorithm: whiten
# center: false
# fix_signs: scores
#
# Model is not fitted yet!

# %%
## Fit the ICS model - equivalent of the function ICS-S3() from the R package ICS
ICSTools.fit!(ics, X);
show(ics)
# Out:
# ICS based on two scatter matrices
# S1: cov2
# S1_args: Dict{Symbol, Any}()
# S2: covW
# S2_args: Dict{Symbol, Any}()
#
# Information on the algorithm:
# algorithm: whiten
# center: false
# fix_signs: scores
#
# The generalized kurtosis measures of the components are:
# IC_1: 6.6248
# IC_2: 6.1884
# IC_3: 5.2813
# IC_4: 4.8105
# IC_5: 3.9477
#
# The coefficient matrix of the linear transformation is:
#                x1           x2           x3           x4           x5
# IC_1        1.19971    -31.83104      2.33736    -18.83172     -5.98021
# IC_2      -19.90580     58.80711      7.75780     19.47824    -28.44422
# IC_3        5.15339     11.03716     13.29070     -4.88970      5.98969
# IC_4       -2.44957    -43.70081     12.92686     -9.08586     21.63247
# IC_5       -4.00962     35.25209     -0.55332     -2.70552     -1.55875
